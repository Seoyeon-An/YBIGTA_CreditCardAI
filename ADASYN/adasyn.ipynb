# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import ADASYN

# %%
#raw_data 불러오기
path = '/content/drive/MyDrive/신용카드AI/'
valid_raw = pd.read_csv(path+'val.csv')
train_raw = pd.read_csv(path+'train.csv')
test_raw = pd.read_csv(path+'test.csv')

#features와 target분리, ID열 제거거

valid_features = valid_raw.drop(['ID','Class'],axis=1)
valid_target = valid_raw[['Class']]

train = train_raw.drop('ID',axis=1)
train_features = train_raw.drop('ID',axis=1)
train_ID = train_raw[['ID']]

test_features = test_raw.drop('ID',axis=1)
test_ID = test_raw[['ID']]

#train_SMOTE = pd.read_csv(path+'SMOTE/train_smote.csv')
#print(train_SMOTE.shape,train_raw.shape, valid_raw.shape, test_raw.shape)
#train_SMOTE.head()

# %%
train['Class'] = ((train.V14 + train.V17 + 10) < 0)

# %%
train['Class'] = train['Class'].astype(int)

# %%
train
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 1       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 2       -0.425966   0.960523  1.141109 -0.168252  0.420987 -0.029728
# 3       -0.644269   1.417964  1.074380 -0.492199  0.948934  0.428118
# 4       -0.894286   0.286157 -0.113192 -0.271526  2.669599  3.721818
# ...           ...        ...       ...       ...       ...       ...
# 113837 -12.516732  10.187818 -8.476671 -2.510473 -4.586669 -1.394465
# 113838   1.884849  -0.143540 -0.999943  1.506772 -0.035300 -0.613638
# 113839  -0.241923   0.712247  0.399806 -0.463406  0.244531 -1.343668
# 113840   0.120316   0.931005 -0.546012 -0.745097  1.130314 -0.235973
# 113841 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
sum(train.Class)
# Out:
# 92

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
trainX_resampled_sm, trainY_resampled_sm = ad.fit_resample(train.drop(columns=['Class']), train.Class)

# %%
trainX_resampled_sm
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0      -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1      -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2      -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3      -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4      -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# ...          ...       ...       ...       ...       ...       ...       ...
# 227501 -3.708916  1.003717 -3.231622  1.368167 -0.758124 -0.620881 -3.151378
# 227502 -4.820711  0.816874 -5.475419  1.746921 -0.470634 -0.526918 -4.148529
# 227503 -5.193084  0.676892 -5.747395  1.728997 -0.439489 -0.469264 -4.286852
# 227504 -5.165057  0.641366 -5.661440  1.663910 -0.383410 -0.484217 -4.221911
# 227505 -2.405512  1.275646 -4.018938  3.022554 -1.058087 -0.657609 -3.789954
#
# ...

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)

trainX_resampled, trainY_resampled = sm.fit_resample(train.drop(columns=['Class']), train.Class)

trainX_resampled
# Out:
#                V1        V2         V3         V4         V5        V6  \
# 0       -1.358354 -1.340163   1.773209   0.379780  -0.503198  1.800499
# 1       -0.966272 -0.185226   1.792993  -0.863291  -0.010309  1.247203
# 2       -0.425966  0.960523   1.141109  -0.168252   0.420987 -0.029728
# 3       -0.644269  1.417964   1.074380  -0.492199   0.948934  0.428118
# 4       -0.894286  0.286157  -0.113192  -0.271526   2.669599  3.721818
# ...           ...       ...        ...        ...        ...       ...
# 227495  -2.870317  1.002704  -3.929599   4.235764   1.158891 -2.211052
# 227496 -13.136956  7.380241 -18.219379  10.584352 -11.780569 -3.635695
# 227497  -2.130029  1.393243  -0.610282   1.097765  -1.145266 -0.779364
# 227498  -1.278324  2.445764  -2.816353   2.337650  -1.357786 -0.952941
# 227499  -7.809948 -2.327980  -4.980668   6.067831  -3.116364  0.057785
#
#                V7        V8        V9        V10  ...       V21       V22  \
# ...

# %%
from imblearn.over_sampling import ADASYN

ad = ADASYN(random_state=42)

trainX_resampled_ad, trainY_resampled_ad = ad.fit_resample(train.drop(columns=['Class']), train.Class)

trainX_resampled_ad
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0      -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1      -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2      -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3      -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4      -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# ...          ...       ...       ...       ...       ...       ...       ...
# 227501 -3.708916  1.003717 -3.231622  1.368167 -0.758124 -0.620881 -3.151378
# 227502 -4.820711  0.816874 -5.475419  1.746921 -0.470634 -0.526918 -4.148529
# 227503 -5.193084  0.676892 -5.747395  1.728997 -0.439489 -0.469264 -4.286852
# 227504 -5.165057  0.641366 -5.661440  1.663910 -0.383410 -0.484217 -4.221911
# 227505 -2.405512  1.275646 -4.018938  3.022554 -1.058087 -0.657609 -3.789954
#
# ...

# %%
#original
plt.scatter(train['V14'], train['V17'], c=train.Class, s=10)
plt.show()
#smote
plt.scatter(trainX_resampled['V14'], trainX_resampled['V17'], c=trainY_resampled, s=10)
plt.show()
#adasyn
plt.scatter(trainX_resampled_ad['V14'], trainX_resampled_ad['V17'], c=trainY_resampled_ad, s=10)
plt.show()

# %%
#original
plt.scatter(train['V3'], train['V7'], c=train.Class, s=10)
plt.show()
#smote
plt.scatter(trainX_resampled['V3'], trainX_resampled['V7'], c=trainY_resampled, s=10)
plt.show()
#adasyn
plt.scatter(trainX_resampled_ad['V3'], trainX_resampled_ad['V7'], c=trainY_resampled_ad, s=10)
plt.show()

# %% [markdown]
# n_neighbors 개수에 따른 차이 비교

# %%
from imblearn.over_sampling import ADASYN

ad2 = ADASYN(random_state=0,n_neighbors=3)
trainX_resampled_ad2, trainY_resampled_ad2 = ad2.fit_resample(train.drop(columns=['Class']), train.Class)

ad3 = ADASYN(random_state=0,n_neighbors=10)
trainX_resampled_ad3, trainY_resampled_ad3 = ad3.fit_resample(train.drop(columns=['Class']), train.Class)

ad4 = ADASYN(random_state=0,n_neighbors=7)
trainX_resampled_ad4, trainY_resampled_ad4 = ad4.fit_resample(train.drop(columns=['Class']), train.Class)

ad5 = ADASYN(random_state=0,n_neighbors=15)
trainX_resampled_ad5, trainY_resampled_ad5 = ad5.fit_resample(train.drop(columns=['Class']), train.Class)

# %%
#original
plt.scatter(train['V14'], train['V17'], c=train.Class, s=10)
plt.show()
#adasyn1
plt.scatter(trainX_resampled_ad['V14'], trainX_resampled_ad['V17'], c=trainY_resampled_ad, s=10)
plt.show()
#adasyn2
plt.scatter(trainX_resampled_ad2['V14'], trainX_resampled_ad2['V17'], c=trainY_resampled_ad2, s=10)
plt.show()
#adasyn3
plt.scatter(trainX_resampled_ad3['V14'], trainX_resampled_ad3['V17'], c=trainY_resampled_ad3, s=10)
plt.show()
#adasyn4
plt.scatter(trainX_resampled_ad4['V14'], trainX_resampled_ad4['V17'], c=trainY_resampled_ad4, s=10)
plt.show()
#adasyn5
plt.scatter(trainX_resampled_ad5['V14'], trainX_resampled_ad5['V17'], c=trainY_resampled_ad5, s=10)
plt.show()

# %%
#original
plt.scatter(train['V3'], train['V7'], c=train.Class, s=10)
plt.show()
#adasyn1
plt.scatter(trainX_resampled_ad['V3'], trainX_resampled_ad['V7'], c=trainY_resampled_ad, s=10)
plt.show()
#adasyn2
plt.scatter(trainX_resampled_ad2['V3'], trainX_resampled_ad2['V7'], c=trainY_resampled_ad2, s=10)
plt.show()
#adasyn3
plt.scatter(trainX_resampled_ad3['V3'], trainX_resampled_ad3['V7'], c=trainY_resampled_ad3, s=10)
plt.show()
#adasyn4
plt.scatter(trainX_resampled_ad4['V3'], trainX_resampled_ad4['V7'], c=trainY_resampled_ad4, s=10)
plt.show()
#adasyn5
plt.scatter(trainX_resampled_ad5['V3'], trainX_resampled_ad5['V7'], c=trainY_resampled_ad5, s=10)
plt.show()

# %% [markdown]
# random_state에 따른 차이 비교

# %%
from imblearn.over_sampling import ADASYN

ad6 = ADASYN(random_state=0)
trainX_resampled_ad6, trainY_resampled_ad6 = ad6.fit_resample(train.drop(columns=['Class']), train.Class)

ad7 = ADASYN(random_state=10)
trainX_resampled_ad7, trainY_resampled_ad7 = ad7.fit_resample(train.drop(columns=['Class']), train.Class)

ad8 = ADASYN(random_state=20)
trainX_resampled_ad8, trainY_resampled_ad8 = ad8.fit_resample(train.drop(columns=['Class']), train.Class)

ad9 = ADASYN(random_state=42)
trainX_resampled_ad9, trainY_resampled_ad9 = ad9.fit_resample(train.drop(columns=['Class']), train.Class)

# %%
#original
plt.scatter(train['V14'], train['V17'], c=train.Class, s=10)
plt.show()
#adasyn6
plt.scatter(trainX_resampled_ad6['V14'], trainX_resampled_ad6['V17'], c=trainY_resampled_ad6, s=10)
plt.show()
#adasyn7
plt.scatter(trainX_resampled_ad7['V14'], trainX_resampled_ad7['V17'], c=trainY_resampled_ad7, s=10)
plt.show()
#adasyn8
plt.scatter(trainX_resampled_ad8['V14'], trainX_resampled_ad8['V17'], c=trainY_resampled_ad8, s=10)
plt.show()
#adasyn9
plt.scatter(trainX_resampled_ad9['V14'], trainX_resampled_ad9['V17'], c=trainY_resampled_ad9, s=10)
plt.show()

# %%
#original
plt.scatter(train['V3'], train['V7'], c=train.Class, s=10)
plt.show()
#adasyn6
plt.scatter(trainX_resampled_ad6['V3'], trainX_resampled_ad6['V7'], c=trainY_resampled_ad6, s=10)
plt.show()
#adasyn7
plt.scatter(trainX_resampled_ad7['V3'], trainX_resampled_ad7['V7'], c=trainY_resampled_ad7, s=10)
plt.show()
#adasyn8
plt.scatter(trainX_resampled_ad8['V3'], trainX_resampled_ad8['V7'], c=trainY_resampled_ad8, s=10)
plt.show()
#adasyn9
plt.scatter(trainX_resampled_ad9['V3'], trainX_resampled_ad9['V7'], c=trainY_resampled_ad9, s=10)
plt.show()

# %% [markdown]
# 괜찮아 보이는 것끼리 조합해보기

# %%
from imblearn.over_sampling import ADASYN

ad10 = ADASYN(random_state=0, n_neighbors=3)
trainX_resampled_ad10, trainY_resampled_ad10 = ad10.fit_resample(train.drop(columns=['Class']), train.Class)

ad11 = ADASYN(random_state=None, n_neighbors=3)
trainX_resampled_ad11, trainY_resampled_ad11 = ad11.fit_resample(train.drop(columns=['Class']), train.Class)

ad12 = ADASYN(random_state=20, n_neighbors=7)
trainX_resampled_ad12, trainY_resampled_ad12 = ad12.fit_resample(train.drop(columns=['Class']), train.Class)

# %%
#original
plt.scatter(train['V14'], train['V17'], c=train.Class, s=10)
plt.show()
#adasyn10
plt.scatter(trainX_resampled_ad10['V14'], trainX_resampled_ad10['V17'], c=trainY_resampled_ad10, s=10)
plt.show()
#adasyn11
plt.scatter(trainX_resampled_ad11['V14'], trainX_resampled_ad11['V17'], c=trainY_resampled_ad11, s=10)
plt.show()
#adasyn12
plt.scatter(trainX_resampled_ad12['V14'], trainX_resampled_ad12['V17'], c=trainY_resampled_ad12, s=10)
plt.show()

# %%
#original
plt.scatter(train['V3'], train['V7'], c=train.Class, s=10)
plt.show()
#adasyn10
plt.scatter(trainX_resampled_ad10['V3'], trainX_resampled_ad10['V7'], c=trainY_resampled_ad10, s=10)
plt.show()
#adasyn11
plt.scatter(trainX_resampled_ad11['V3'], trainX_resampled_ad11['V7'], c=trainY_resampled_ad11, s=10)
plt.show()
#adasyn12
plt.scatter(trainX_resampled_ad12['V3'], trainX_resampled_ad12['V7'], c=trainY_resampled_ad12, s=10)
plt.show()

# %%
pd.concat([trainX_resampled_ad10,trainY_resampled_ad10],axis=1).to_csv(path+'ADASYN/train_adasyn1.csv')
pd.concat([trainX_resampled_ad11,trainY_resampled_ad11],axis=1).to_csv(path+'ADASYN/train_adasyn2.csv')
pd.concat([trainX_resampled_ad12,trainY_resampled_ad12],axis=1).to_csv(path+'ADASYN/train_adasyn3.csv')
