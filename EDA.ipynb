# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
import os

# %%
cur_path = os.getcwd()

trainpath = f'{cur_path}/data/train.csv'
testpath=f'{cur_path}/data/test.csv'
valpath=f'{cur_path}/data/val.csv'
submissionpath= f'{cur_path}/data/sample_submission.csv'

train=pd.read_csv(trainpath)
test=pd.read_csv(testpath)
val=pd.read_csv(valpath)
submission=pd.read_csv(submissionpath)

# %%
val_corr = val.corr()
sns.heatmap(val_corr, cmap='viridis')
# V30과 ID correlation 매우 높음
# Out:
# <Axes: >

# %%
golds = val[val['Class']==1].index.to_list()
golds = [str(gold) for gold in golds]
frauds = val[val['Class']==0].index.to_list()
frauds = [str(fraud) for fraud in frauds]

# %% [markdown]
# # 다른 column과 scatter를 찍어봤을 때
# 오류가 적음: V14

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V1, val[val['Class']==0].V2, color='green')

axs[0].scatter(val[val['Class']==1].V1, val[val['Class']==1].V2, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V1.values[i], val[val['Class']==1].V2.values[i]))

axs[1].scatter(val[val['Class']==0].V1, val[val['Class']==0].V3, color='green')

axs[1].scatter(val[val['Class']==1].V1, val[val['Class']==1].V3, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V1.values[i], val[val['Class']==1].V3.values[i]))

plt.show()

# %% [markdown]
# ## V2?

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V2, val[val['Class']==0].V3, color='green')

axs[0].scatter(val[val['Class']==1].V2, val[val['Class']==1].V3, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V2.values[i], val[val['Class']==1].V3.values[i]))

axs[1].scatter(val[val['Class']==0].V2, val[val['Class']==0].V4, color='green')

axs[1].scatter(val[val['Class']==1].V2, val[val['Class']==1].V4, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V2.values[i], val[val['Class']==1].V4.values[i]))


plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V2, val[val['Class']==0].V5, color='green')

axs[0].scatter(val[val['Class']==1].V2, val[val['Class']==1].V5, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V2.values[i], val[val['Class']==1].V5.values[i]))

axs[1].scatter(val[val['Class']==0].V2, val[val['Class']==0].V6, color='green')

axs[1].scatter(val[val['Class']==1].V2, val[val['Class']==1].V6, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V2.values[i], val[val['Class']==1].V6.values[i]))


plt.show()

# %% [markdown]
# # V3

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V3, val[val['Class']==0].V4, color='green')

axs[0].scatter(val[val['Class']==1].V3, val[val['Class']==1].V4, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V4.values[i]))

axs[1].scatter(val[val['Class']==0].V3, val[val['Class']==0].V5, color='green')

axs[1].scatter(val[val['Class']==1].V3, val[val['Class']==1].V5, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V5.values[i]))


plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V3, val[val['Class']==0].V6, color='green')

axs[0].scatter(val[val['Class']==1].V3, val[val['Class']==1].V6, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V6.values[i]))

axs[1].scatter(val[val['Class']==0].V3, val[val['Class']==0].V7, color='green')

axs[1].scatter(val[val['Class']==1].V3, val[val['Class']==1].V7, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V7.values[i]))


plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V3, val[val['Class']==0].V8, color='green')

axs[0].scatter(val[val['Class']==1].V3, val[val['Class']==1].V8, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V8.values[i]))

axs[1].scatter(val[val['Class']==0].V3, val[val['Class']==0].V9, color='green')

axs[1].scatter(val[val['Class']==1].V3, val[val['Class']==1].V9, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V9.values[i]))


plt.show()

# %% [markdown]
# ## V3

# %%
plt.scatter(val[val['Class']==0].V3, val[val['Class']==0].V7, color='green')
# for i, txt in enumerate(golds):
#     plt.annotate(txt, (val[val['Class']==0].V3.values[i], val[val['Class']==0].V7.values[i]))

plt.scatter(val[val['Class']==1].V3, val[val['Class']==1].V7, color='red')
for i, txt in enumerate(golds):
    plt.annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V7.values[i]))

plt.show()

# %%
plt.scatter(val[val['Class']==0].V3, val[val['Class']==0].V8, color='green')

plt.scatter(val[val['Class']==1].V3, val[val['Class']==1].V8, color='red')
for i, txt in enumerate(golds):
    plt.annotate(txt, (val[val['Class']==1].V3.values[i], val[val['Class']==1].V8.values[i]))

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V14, val[val['Class']==0].V17, color='green')

axs[0].scatter(val[val['Class']==1].V14, val[val['Class']==1].V17, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V14.values[i], val[val['Class']==1].V17.values[i]))

axs[1].scatter(val[val['Class']==0].V14, val[val['Class']==0].V18, color='green')

axs[1].scatter(val[val['Class']==1].V14, val[val['Class']==1].V18, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V14.values[i], val[val['Class']==1].V18.values[i]))


plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

axs[0].scatter(val[val['Class']==0].V14, val[val['Class']==0].V12, color='green')

axs[0].scatter(val[val['Class']==1].V14, val[val['Class']==1].V12, color='red')
for i, txt in enumerate(golds):
    axs[0].annotate(txt, (val[val['Class']==1].V14.values[i], val[val['Class']==1].V12.values[i]))

axs[1].scatter(val[val['Class']==0].V14, val[val['Class']==0].V11, color='green')

axs[1].scatter(val[val['Class']==1].V14, val[val['Class']==1].V11, color='red')
for i, txt in enumerate(golds):
    axs[1].annotate(txt, (val[val['Class']==1].V14.values[i], val[val['Class']==1].V11.values[i]))


plt.show()
